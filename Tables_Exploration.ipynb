# %% [markdown]
# # Inizialization

# %%
import pandas as pd

# %%
drivers_path = "/content/drive/.../drivers.csv"
trucks_path = "/content/drive/.../trucks.csv"
trailers_path = "/content/drive/.../trailers.csv"
customers_path = "/content/drive/.../customers.csv"
facilities_path = "/content/drive/.../facilities.csv"
routes_path = "/content/drive/.../routes.csv"
loads_path = "/content/drive/.../loads.csv"
trips_path = "/content/drive/.../trips.csv"
fuel_purchases_path = "/content/drive/.../fuel_purchases.csv"
maintenance_records_path = "/content/drive/.../maintenance_records.csv"
delivery_events_path = "/content/drive/.../delivery_events.csv"
safety_incidents_path = "/content/drive/.../safety_incidents.csv"
driver_monthly_metrics_path = "/content/drive/.../driver_monthly_metrics.csv"
truck_utilization_metrics_path = "/content/drive/.../truck_utilization_metrics.csv"



df_drivers = pd.read_csv(drivers_path)
df_trucks = pd.read_csv(trucks_path)
df_trailers = pd.read_csv(trailers_path)
df_customers = pd.read_csv(customers_path)
df_facilities = pd.read_csv(facilities_path)
df_routes = pd.read_csv(routes_path)
df_loads = pd.read_csv(loads_path)
df_trips = pd.read_csv(trips_path)
df_fuel_purchases = pd.read_csv(fuel_purchases_path)
df_maintenance_records = pd.read_csv(maintenance_records_path)
df_delivery_events = pd.read_csv(delivery_events_path)
df_safety_incidents = pd.read_csv(safety_incidents_path)
df_driver_monthly_metrics = pd.read_csv(driver_monthly_metrics_path)
df_truck_utilization_metrics = pd.read_csv(truck_utilization_metrics_path)

# %% [markdown]
# # Datasets exploration

# %%
df_drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   driver_id          150 non-null    object
#  1   first_name         150 non-null    object
#  2   last_name          150 non-null    object
#  3   hire_date          150 non-null    object
#  4   termination_date   26 non-null     object
#  5   license_number     150 non-null    object
#  6   license_state      150 non-null    object
#  7   date_of_birth      150 non-null    object
#  8   home_terminal      150 non-null    object
#  9   employment_status  150 non-null    object
#  10  cdl_class          150 non-null    object
#  11  years_experience   150 non-null    int64
# dtypes: int64(1), object(11)
# memory usage: 14.2+ KB

# %%
df_drivers.head(15)
# Out:
#    driver_id first_name  last_name   hire_date termination_date  \
# 0   DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# 1   DRV00002    William     Martin  2020-10-02              NaN
# 2   DRV00003    Charles  Hernandez  2021-09-21              NaN
# 3   DRV00004    Barbara      Brown  2013-09-08              NaN
# 4   DRV00005       Mary   Martinez  2018-12-02              NaN
# 5   DRV00006     Robert     Taylor  2019-04-04              NaN
# 6   DRV00007      James   Martinez  2019-07-02       2021-05-17
# 7   DRV00008    Barbara     Wilson  2020-06-09       2021-01-23
# 8   DRV00009      Karen  Hernandez  2013-09-29              NaN
# 9   DRV00010      Sarah   Gonzalez  2020-11-08              NaN
# 10  DRV00011    Michael   Martinez  2014-06-01              NaN
# 11  DRV00012     Robert      Moore  2013-09-12              NaN
# 12  DRV00013    Jessica      Jones  2015-11-21              NaN
# 13  DRV00014    Richard     Miller  2021-01-10              NaN
# ...

# %%
df_trucks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   truck_id               120 non-null    object
#  1   unit_number            120 non-null    int64
#  2   make                   120 non-null    object
#  3   model_year             120 non-null    int64
#  4   vin                    120 non-null    object
#  5   acquisition_date       120 non-null    object
#  6   acquisition_mileage    120 non-null    int64
#  7   fuel_type              120 non-null    object
#  8   tank_capacity_gallons  120 non-null    int64
#  9   status                 120 non-null    object
#  10  home_terminal          120 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 10.4+ KB

# %%
df_trucks.head(15)
# Out:
#     truck_id  unit_number           make  model_year                 vin  \
# 0   TRK00001         3463      Peterbilt        2016  1VV205190335317039
# 1   TRK00002         6461       Kenworth        2015  1NV753749606229960
# 2   TRK00003         2335      Peterbilt        2018  1NT803101860493229
# 3   TRK00004         3317   Freightliner        2015  1VV131945381692351
# 4   TRK00005         6731   Freightliner        2016  1FT822215709701985
# 5   TRK00006         6082       Kenworth        2017  1VV963516965177788
# 6   TRK00007         7421          Volvo        2019  1MV134100489809236
# 7   TRK00008         3112           Mack        2015  1MV426140684859204
# 8   TRK00009         2388  International        2015  1VU871233565012431
# 9   TRK00010         6072          Volvo        2015  1MU182160377362421
# 10  TRK00011         7171   Freightliner        2015  1FT567947164925037
# 11  TRK00012         6381   Freightliner        2015  1MU483021764762154
# ...

# %%
df_trailers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trailer_id        180 non-null    object
#  1   trailer_number    180 non-null    int64
#  2   trailer_type      180 non-null    object
#  3   length_feet       180 non-null    int64
#  4   model_year        180 non-null    int64
#  5   vin               180 non-null    object
#  6   acquisition_date  180 non-null    object
#  7   status            180 non-null    object
#  8   current_location  180 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 12.8+ KB

# %%
df_trailers.head(15)
# Out:
#    trailer_id  trailer_number  trailer_type  length_feet  model_year  \
# 0    TRL00001            4290  Refrigerated           53        2016
# 1    TRL00002            8848       Dry Van           53        2018
# 2    TRL00003            6147       Dry Van           53        2022
# 3    TRL00004            3910       Dry Van           53        2024
# 4    TRL00005            7524       Dry Van           53        2016
# 5    TRL00006            6228  Refrigerated           53        2023
# 6    TRL00007            5775       Dry Van           53        2015
# 7    TRL00008            9044  Refrigerated           53        2020
# 8    TRL00009            4971       Dry Van           53        2020
# 9    TRL00010            6339  Refrigerated           53        2017
# 10   TRL00011            7161       Dry Van           53        2021
# 11   TRL00012            5592  Refrigerated           53        2024
# 12   TRL00013            7437  Refrigerated           53        2021
# ...

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               200 non-null    object
#  1   customer_name             200 non-null    object
#  2   customer_type             200 non-null    object
#  3   credit_terms_days         200 non-null    int64
#  4   primary_freight_type      200 non-null    object
#  5   account_status            200 non-null    object
#  6   contract_start_date       200 non-null    object
#  7   annual_revenue_potential  200 non-null    int64
# dtypes: int64(2), object(6)
# memory usage: 12.6+ KB

# %%
df_customers.head(15)
# Out:
#    customer_id          customer_name customer_type  credit_terms_days  \
# 0    CUST00001        Metro Wholesale     Dedicated                 60
# 1    CUST00002        National Retail      Contract                 30
# 2    CUST00003         XYZ Industries      Contract                 30
# 3    CUST00004          American Corp      Contract                 15
# 4    CUST00005  American Distribution          Spot                 45
# 5    CUST00006    American Industries     Dedicated                 30
# 6    CUST00007  Superior Distribution          Spot                 30
# 7    CUST00008     American Logistics      Contract                 30
# 8    CUST00009          XYZ Wholesale      Contract                 30
# 9    CUST00010     National Logistics     Dedicated                 45
# 10   CUST00011            First Group     Dedicated                 15
# 11   CUST00012       ABC Distribution     Dedicated                 30
# ...

# %%
df_facilities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   facility_id      50 non-null     object
#  1   facility_name    50 non-null     object
#  2   facility_type    50 non-null     object
#  3   city             50 non-null     object
#  4   state            50 non-null     object
#  5   latitude         50 non-null     float64
#  6   longitude        50 non-null     float64
#  7   dock_doors       50 non-null     int64
#  8   operating_hours  50 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 3.6+ KB

# %%
df_facilities.head(15)
# Out:
#    facility_id                     facility_name        facility_type  \
# 0     FAC00001       Houston Distribution Center           Cross-Dock
# 1     FAC00002                   Kansas City Hub           Cross-Dock
# 2     FAC00003     Charlotte Distribution Center  Distribution Center
# 3     FAC00004       Chicago Distribution Center  Distribution Center
# 4     FAC00005                  Indianapolis Hub  Distribution Center
# 5     FAC00006                 Atlanta Warehouse  Distribution Center
# 6     FAC00007                 Detroit Warehouse             Terminal
# 7     FAC00008                  Philadelphia Hub           Cross-Dock
# 8     FAC00009     Nashville Distribution Center             Terminal
# 9     FAC00010  Indianapolis Distribution Center            Warehouse
# 10    FAC00011     Nashville Distribution Center           Cross-Dock
# 11    FAC00012       Atlanta Distribution Center  Distribution Center
# ...

# %%
df_routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   route_id                58 non-null     object
#  1   origin_city             58 non-null     object
#  2   origin_state            58 non-null     object
#  3   destination_city        58 non-null     object
#  4   destination_state       58 non-null     object
#  5   typical_distance_miles  58 non-null     int64
#  6   base_rate_per_mile      58 non-null     float64
#  7   fuel_surcharge_rate     58 non-null     float64
#  8   typical_transit_days    58 non-null     int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 4.2+ KB

# %%
df_routes.head(15)
# Out:
#     route_id   origin_city origin_state destination_city destination_state  \
# 0   RTE00001       Atlanta           GA          Chicago                IL
# 1   RTE00002       Atlanta           GA            Miami                FL
# 2   RTE00003       Chicago           IL      Los Angeles                CA
# 3   RTE00004       Chicago           IL         Portland                OR
# 4   RTE00005       Chicago           IL        Las Vegas                NV
# 5   RTE00006       Chicago           IL        Charlotte                NC
# 6   RTE00007        Dallas           TX         New York                NY
# 7   RTE00008        Dallas           TX           Denver                CO
# 8   RTE00009        Dallas           TX     Indianapolis                IN
# 9   RTE00010      New York           NY     Philadelphia                PA
# 10  RTE00011      New York           NY         Columbus                OH
# ...

# %%
df_loads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85410 entries, 0 to 85409
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   load_id              85410 non-null  object
#  1   customer_id          85410 non-null  object
#  2   route_id             85410 non-null  object
#  3   load_date            85410 non-null  object
#  4   load_type            85410 non-null  object
#  5   weight_lbs           85410 non-null  int64
#  6   pieces               85410 non-null  int64
#  7   revenue              85410 non-null  float64
#  8   fuel_surcharge       85410 non-null  float64
#  9   accessorial_charges  85410 non-null  int64
#  10  load_status          85410 non-null  object
#  11  booking_type         85410 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 7.8+ MB

# %%
df_loads.head(15)
# Out:
#          load_id customer_id  route_id   load_date     load_type  weight_lbs  \
# 0   LOAD00000001   CUST00183  RTE00019  2022-01-01       Dry Van       19178
# 1   LOAD00000002   CUST00076  RTE00058  2022-01-01       Dry Van       27761
# 2   LOAD00000003   CUST00027  RTE00048  2022-01-01  Refrigerated       35594
# 3   LOAD00000004   CUST00088  RTE00013  2022-01-01  Refrigerated       33274
# 4   LOAD00000005   CUST00185  RTE00020  2022-01-01       Dry Van       40257
# 5   LOAD00000006   CUST00193  RTE00004  2022-01-01  Refrigerated       34671
# 6   LOAD00000007   CUST00169  RTE00038  2022-01-01       Dry Van       14530
# 7   LOAD00000008   CUST00049  RTE00016  2022-01-01  Refrigerated       16927
# 8   LOAD00000009   CUST00075  RTE00025  2022-01-01  Refrigerated       38964
# 9   LOAD00000010   CUST00079  RTE00025  2022-01-01  Refrigerated       29233
# 10  LOAD00000011   CUST00127  RTE00058  2022-01-01  Refrigerated       34882
# ...

# %%
df_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85410 entries, 0 to 85409
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trip_id                85410 non-null  object
#  1   load_id                85410 non-null  object
#  2   driver_id              83696 non-null  object
#  3   truck_id               83738 non-null  object
#  4   trailer_id             83730 non-null  object
#  5   dispatch_date          85410 non-null  object
#  6   actual_distance_miles  85410 non-null  int64
#  7   actual_duration_hours  85410 non-null  float64
#  8   fuel_gallons_used      85410 non-null  float64
#  9   average_mpg            85410 non-null  float64
#  10  idle_time_hours        85410 non-null  float64
#  11  trip_status            85410 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 7.8+ MB

# %%
df_trips.head(15)
# Out:
#          trip_id       load_id driver_id  truck_id trailer_id dispatch_date  \
# 0   TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167    2022-01-01
# 1   TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082    2022-01-01
# 2   TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138    2022-01-01
# 3   TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018    2022-01-01
# 4   TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054    2022-01-01
# 5   TRIP00000006  LOAD00000006  DRV00120  TRK00062   TRL00007    2022-01-01
# 6   TRIP00000007  LOAD00000007  DRV00055  TRK00002   TRL00093    2022-01-01
# 7   TRIP00000008  LOAD00000008  DRV00065  TRK00035   TRL00148    2022-01-01
# 8   TRIP00000009  LOAD00000009  DRV00129  TRK00014   TRL00083    2022-01-01
# 9   TRIP00000010  LOAD00000010  DRV00029  TRK00116   TRL00126    2022-01-01
# 10  TRIP00000011  LOAD00000011  DRV00132  TRK00085   TRL00083    2022-01-01
# ...

# %%
df_fuel_purchases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196442 entries, 0 to 196441
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   fuel_purchase_id  196442 non-null  object
#  1   trip_id           196442 non-null  object
#  2   truck_id          192562 non-null  object
#  3   driver_id         192454 non-null  object
#  4   purchase_date     196442 non-null  object
#  5   location_city     196442 non-null  object
#  6   location_state    196442 non-null  object
#  7   gallons           196442 non-null  float64
#  8   price_per_gallon  196442 non-null  float64
#  9   total_cost        196442 non-null  float64
#  10  fuel_card_number  196442 non-null  object
# dtypes: float64(3), object(8)
# memory usage: 16.5+ MB

# %%
df_fuel_purchases.head(15)
# Out:
#    fuel_purchase_id       trip_id  truck_id driver_id        purchase_date  \
# 0      FUEL00000001  TRIP00051284  TRK00045  DRV00102  2023-10-22 05:00:00
# 1      FUEL00000002  TRIP00073723  TRK00013       NaN  2024-08-04 08:00:00
# 2      FUEL00000003  TRIP00018286  TRK00024  DRV00142  2022-08-23 13:00:00
# 3      FUEL00000004  TRIP00008465  TRK00018  DRV00047  2022-04-20 00:00:00
# 4      FUEL00000005  TRIP00069700  TRK00054       NaN  2024-06-13 09:00:00
# 5      FUEL00000006  TRIP00062650  TRK00012  DRV00104  2024-03-18 23:00:00
# 6      FUEL00000007  TRIP00000851  TRK00072  DRV00127  2022-01-11 21:00:00
# 7      FUEL00000008  TRIP00012033  TRK00073  DRV00084  2022-06-06 00:00:00
# 8      FUEL00000009  TRIP00023596  TRK00101  DRV00080  2022-10-28 02:00:00
# 9      FUEL00000010  TRIP00037859  TRK00085  DRV00002  2023-04-30 09:00:00
# 10     FUEL00000011  TRIP00027109  TRK00103  DRV00038  2022-12-12 07:00:00
# ...

# %%
df_maintenance_records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2920 entries, 0 to 2919
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   maintenance_id       2920 non-null   object
#  1   truck_id             2920 non-null   object
#  2   maintenance_date     2920 non-null   object
#  3   maintenance_type     2920 non-null   object
#  4   odometer_reading     2920 non-null   int64
#  5   labor_hours          2920 non-null   float64
#  6   labor_cost           2920 non-null   float64
#  7   parts_cost           2920 non-null   float64
#  8   total_cost           2920 non-null   float64
#  9   facility_location    2920 non-null   object
#  10  downtime_hours       2920 non-null   float64
#  11  service_description  2920 non-null   object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 273.9+ KB

# %%
df_maintenance_records.head(15)
# Out:
#    maintenance_id  truck_id maintenance_date maintenance_type  \
# 0   MAINT00000001  TRK00085       2022-01-01       Inspection
# 1   MAINT00000002  TRK00041       2022-01-01             Tire
# 2   MAINT00000003  TRK00090       2022-01-01       Preventive
# 3   MAINT00000004  TRK00056       2022-01-02       Inspection
# 4   MAINT00000005  TRK00029       2022-01-02           Repair
# 5   MAINT00000006  TRK00120       2022-01-02       Preventive
# 6   MAINT00000007  TRK00017       2022-01-02           Repair
# 7   MAINT00000008  TRK00038       2022-01-03             Tire
# 8   MAINT00000009  TRK00054       2022-01-03       Inspection
# 9   MAINT00000010  TRK00076       2022-01-03       Inspection
# 10  MAINT00000011  TRK00075       2022-01-04       Preventive
# 11  MAINT00000012  TRK00075       2022-01-05             Tire
# 12  MAINT00000013  TRK00102       2022-01-05       Preventive
# 13  MAINT00000014  TRK00107       2022-01-05     Transmission
# ...

# %%
df_delivery_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170820 entries, 0 to 170819
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   event_id            170820 non-null  object
#  1   load_id             170820 non-null  object
#  2   trip_id             170820 non-null  object
#  3   event_type          170820 non-null  object
#  4   facility_id         170820 non-null  object
#  5   scheduled_datetime  170820 non-null  object
#  6   actual_datetime     170820 non-null  object
#  7   detention_minutes   170820 non-null  int64
#  8   on_time_flag        170820 non-null  bool
#  9   location_city       170820 non-null  object
#  10  location_state      170820 non-null  object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 13.2+ MB

# %%
df_delivery_events.head(15)
# Out:
#        event_id       load_id       trip_id event_type facility_id  \
# 0   EVT00000001  LOAD00000001  TRIP00000001     Pickup    FAC00034
# 1   EVT00000002  LOAD00000001  TRIP00000001   Delivery    FAC00046
# 2   EVT00000003  LOAD00000002  TRIP00000002     Pickup    FAC00015
# 3   EVT00000004  LOAD00000002  TRIP00000002   Delivery    FAC00050
# 4   EVT00000005  LOAD00000003  TRIP00000003     Pickup    FAC00001
# 5   EVT00000006  LOAD00000003  TRIP00000003   Delivery    FAC00022
# 6   EVT00000007  LOAD00000004  TRIP00000004     Pickup    FAC00029
# 7   EVT00000008  LOAD00000004  TRIP00000004   Delivery    FAC00037
# 8   EVT00000009  LOAD00000005  TRIP00000005     Pickup    FAC00046
# 9   EVT00000010  LOAD00000005  TRIP00000005   Delivery    FAC00050
# 10  EVT00000011  LOAD00000006  TRIP00000006     Pickup    FAC00043
# 11  EVT00000012  LOAD00000006  TRIP00000006   Delivery    FAC00021
# 12  EVT00000013  LOAD00000007  TRIP00000007     Pickup    FAC00006
# ...

# %%
df_safety_incidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   incident_id          170 non-null    object
#  1   trip_id              170 non-null    object
#  2   truck_id             169 non-null    object
#  3   driver_id            169 non-null    object
#  4   incident_date        170 non-null    object
#  5   incident_type        170 non-null    object
#  6   location_city        170 non-null    object
#  7   location_state       170 non-null    object
#  8   at_fault_flag        170 non-null    bool
#  9   injury_flag          170 non-null    bool
#  10  vehicle_damage_cost  170 non-null    float64
#  11  cargo_damage_cost    170 non-null    float64
#  12  claim_amount         170 non-null    float64
#  13  preventable_flag     170 non-null    bool
#  14  description          170 non-null    object
# ...

# %%
df_safety_incidents.head(15)
# Out:
#     incident_id       trip_id  truck_id driver_id        incident_date  \
# 0   INC00000001  TRIP00036079  TRK00006  DRV00006  2023-04-09 14:00:00
# 1   INC00000002  TRIP00032462  TRK00084  DRV00006  2023-02-19 11:00:00
# 2   INC00000003  TRIP00067583  TRK00106  DRV00119  2024-05-20 01:00:00
# 3   INC00000004  TRIP00049128  TRK00085  DRV00134  2023-09-26 03:00:00
# 4   INC00000005  TRIP00062884  TRK00014  DRV00133  2024-03-20 14:00:00
# 5   INC00000006  TRIP00004361  TRK00007  DRV00005  2022-02-27 18:00:00
# 6   INC00000007  TRIP00012773  TRK00007  DRV00109  2022-06-13 02:00:00
# 7   INC00000008  TRIP00072329  TRK00115  DRV00060  2024-07-17 20:00:00
# 8   INC00000009  TRIP00043143  TRK00107  DRV00003  2023-07-08 02:00:00
# 9   INC00000010  TRIP00068700  TRK00074  DRV00132  2024-06-03 04:00:00
# 10  INC00000011  TRIP00022792  TRK00007  DRV00041  2022-10-18 02:00:00
# 11  INC00000012  TRIP00048458  TRK00007  DRV00147  2023-09-16 03:00:00
# ...

# %%
df_driver_monthly_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4464 entries, 0 to 4463
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   driver_id              4464 non-null   object
#  1   month                  4464 non-null   object
#  2   trips_completed        4464 non-null   int64
#  3   total_miles            4464 non-null   int64
#  4   total_revenue          4464 non-null   float64
#  5   average_mpg            4464 non-null   float64
#  6   total_fuel_gallons     4464 non-null   float64
#  7   on_time_delivery_rate  4464 non-null   float64
#  8   average_idle_hours     4464 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 314.0+ KB

# %%
df_driver_monthly_metrics.head(15)
# Out:
#    driver_id       month  trips_completed  total_miles  total_revenue  \
# 0   DRV00001  2022-01-01               26        36620       79141.59
# 1   DRV00001  2022-02-01                9        13515       27133.87
# 2   DRV00001  2022-03-01               20        30361       62399.62
# 3   DRV00001  2022-04-01               19        28127       68161.13
# 4   DRV00001  2022-05-01               14        16071       36256.82
# 5   DRV00001  2022-06-01               13        17291       39709.91
# 6   DRV00001  2022-07-01               21        32772       66855.24
# 7   DRV00001  2022-08-01               20        27010       58514.48
# 8   DRV00001  2022-09-01               20        30866       72027.99
# 9   DRV00001  2022-10-01               12        23943       53495.80
# 10  DRV00001  2022-11-01               16        21223       43790.85
# 11  DRV00001  2022-12-01               16        21622       46003.88
# ...

# %%
df_truck_utilization_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3312 entries, 0 to 3311
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   truck_id            3312 non-null   object
#  1   month               3312 non-null   object
#  2   trips_completed     3312 non-null   int64
#  3   total_miles         3312 non-null   int64
#  4   total_revenue       3312 non-null   float64
#  5   average_mpg         3312 non-null   float64
#  6   maintenance_events  3312 non-null   int64
#  7   maintenance_cost    3312 non-null   float64
#  8   downtime_hours      3312 non-null   float64
#  9   utilization_rate    3312 non-null   float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 258.9+ KB

# %%
df_truck_utilization_metrics.head(15)
# Out:
#     truck_id       month  trips_completed  total_miles  total_revenue  \
# 0   TRK00001  2022-01-01               22        39269       84792.02
# 1   TRK00001  2022-02-01               27        40787       88809.05
# 2   TRK00001  2022-03-01               34        57422      120453.71
# 3   TRK00001  2022-04-01               20        34428       73531.28
# 4   TRK00001  2022-05-01               16        20851       40791.53
# 5   TRK00001  2022-06-01               31        47085      101659.37
# 6   TRK00001  2022-07-01               28        38038       84143.99
# 7   TRK00001  2022-08-01               27        35902       82253.78
# 8   TRK00001  2022-09-01               24        40898       88581.76
# 9   TRK00001  2022-10-01               37        51364      108130.03
# 10  TRK00001  2022-11-01               27        40313       79626.57
# 11  TRK00001  2022-12-01               26        34882       71982.89
# ...
